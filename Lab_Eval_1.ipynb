# %%
import pandas as pd
import numpy as np
import numpy as random
import matplotlib.pyplot as plt
from numpy import percentile

# %%
#1
df=pd.read_csv('/content/Absenteism_at_work.csv')

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#2
df.drop(['Son', 'Pet'], axis=1)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#2
dff=df.dropna()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                --------------  -----
# ...

# %%
#3
df.isnull().sum()
df.fillna(88,inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    object
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
#4
boxplot=df.boxplot(column=['Reason for absence','Month of absence'])

# %%
#5
print(df['Weight'].corr(df['Height']))
# Out:
# 0.30680183475759065

# %%
#6
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
#7
df.head(3)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0               2,39,554  ...                     0          1    2
# 1               2,39,554  ...                     1          1    1
# 2               2,39,554  ...                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ...

# %%
#8
df.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 736   37               2,64,604  ...                     0          3    1
# 737   40               2,71,219  ...                     0          1    1
# ...

# %%
#9
df[df['ID'] == '03']
# Out:
# Empty DataFrame
# Columns: [ID, Reason for absence, Month of absence, Day of the week, Seasons, Transportation expense, Distance from Residence to Work, Service time, Age, Work load Average/day , Hit target, Disciplinary failure, Education, Son, Social drinker, Social smoker, Pet, Weight, Height, Body mass index, Absenteeism time in hours]
# Index: []
#
# [0 rows x 21 columns]

# %%
#10
df.info()
#therfore 740 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    object
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
#11
display(df.iloc[:1, :5])
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons
# 0  11                  26                 7                3        1

# %%
#12
df12 = df[df['Reason for absence'] == 9]
df12.groupby('Reason for absence').count()
# Out:
#                     ID  Month of absence  Day of the week  Seasons  \
# Reason for absence
# 9                    4                 4                4        4
#
#                     Transportation expense  Distance from Residence to Work  \
# Reason for absence
# 9                                        4                                4
#
#                     Service time  Age  Work load Average/day   Hit target  \
# Reason for absence
# 9                              4    4                       4           4
#
#                     Disciplinary failure  Education  Son  Social drinker  \
# Reason for absence
# 9                                      4          4    4               4
#
#                     Social smoker  Pet  Weight  Height  Body mass index  \
# Reason for absence
# 9                               4    4       4       4                4
#
#                     Absenteeism time in hours
# Reason for absence
# 9                                           4

# %%
#13
df1 = df[df['Body mass index']>30]
print(df1)
df2 = df[df['Body mass index']>=25]
df3 = df2[df2['Body mass index']<=30]
print(df3)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 5     3                  23                 7                6        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# ..   ..                 ...               ...              ...      ...
# 714   2                   0                 6                2        3
# 716  36                  19                 6                5        3
# 725   5                  26                 7                4        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#14
a=df.loc[df.Education==1]
print(a['Age'].mean())

b=df.loc[df.Education==2]
print(b['Age'].mean())

c=df.loc[df.Education==3]
print(c['Age'].mean())
# Out:
# 37.14238952536825
# 34.0
# 32.29113924050633

# %%
#15
print(df.mean()['Transportation expense'])
print(df.var()['Transportation expense'])
# Out:
# 221.32972972972973
# 4482.600197491131
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#16
print(df['Social drinker'].skew())
plt.hist(df['Social drinker'], bins=20)
plt.show()
#this skew is negitive
# Out:
# -0.2733267156901403
